# %% [markdown]
# # PART III

# %% [markdown]
# 4. What is the effect caused by COVID on Amsterdam Schiphol Airport compared to other Dutch airports?

# %%
import pandas as pd 
import numpy as np
import math
import scipy

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook"

# %% [markdown]
# Import and preparation of the covid data

# %%
filepath = 'Data_Sets/Dutch Airports.csv'
DutchAirports = pd.read_csv(filepath, delimiter=';')
 
DutchAirports = DutchAirports.drop(['Aircraft movements/Cross-country flights (number)', 'Aircraft movements/Local flights (number)', 'Commercial air traffic/Flights/All flights/Scheduled (number)'], axis = 1)
DutchAirports = DutchAirports.set_index('Airports')
DutchAirports = DutchAirports.T
DutchAirports = DutchAirports.drop(['Total Dutch airports'], axis = 1)
DutchAirports
#DutchAirports_EHAM = DutchAirports.drop(['Rotterdam The Hague Airport','Eindhoven Airport','Maastricht Aachen Airport','Groningen Airport Eelde'], axis = 1)
#DutchAirports_EHAM
# Out:
# Airports                                           Amsterdam Airport Schiphol  \
# Periods                                                                  2018
# Commercial air traffic/Flights/All flights/Tota...                     499444
# Commercial air traffic/Passengers/Total passeng...                   70956594
# Commercial air traffic/Cargo/Total cargo/Total ...                    1708132
# Commercial air traffic/Mail/Total mail/Total ma...                      21486
#
# Airports                                           Amsterdam Airport Schiphol  \
# Periods                                                                  2019
# Commercial air traffic/Flights/All flights/Tota...                     496827
# Commercial air traffic/Passengers/Total passeng...                   71679729
# Commercial air traffic/Cargo/Total cargo/Total ...                    1570246
# Commercial air traffic/Mail/Total mail/Total ma...                      21959
#
# Airports                                           Amsterdam Airport Schiphol  \
# Periods                                                         2020 January*
# Commercial air traffic/Flights/All flights/Tota...                      37567
# Commercial air traffic/Passengers/Total passeng...                    5074773
# Commercial air traffic/Cargo/Total cargo/Total ...                     113080
# Commercial air traffic/Mail/Total mail/Total ma...                       1908
#
# Airports                                           Amsterdam Airport Schiphol  \
# Periods                                                        2020 February*
# Commercial air traffic/Flights/All flights/Tota...                      34979
# Commercial air traffic/Passengers/Total passeng...                    4719769
# Commercial air traffic/Cargo/Total cargo/Total ...                     116293
# Commercial air traffic/Mail/Total mail/Total ma...                       1491
#
# Airports                                           Amsterdam Airport Schiphol  \
# Periods                                                           2020 March*
# Commercial air traffic/Flights/All flights/Tota...                      25155
# Commercial air traffic/Passengers/Total passeng...                    2476372
# Commercial air traffic/Cargo/Total cargo/Total ...                     120481
# Commercial air traffic/Mail/Total mail/Total ma...                       1167
#
# Airports                                           Amsterdam Airport Schiphol  \
# Periods                                                           2020 April*
# Commercial air traffic/Flights/All flights/Tota...                       4236
# Commercial air traffic/Passengers/Total passeng...                     126015
# Commercial air traffic/Cargo/Total cargo/Total ...                      93255
# Commercial air traffic/Mail/Total mail/Total ma...                        382
#
# Airports                                           Amsterdam Airport Schiphol  \
# Periods                                                             2020 May*
# Commercial air traffic/Flights/All flights/Tota...                       5873
# Commercial air traffic/Passengers/Total passeng...                     207827
# Commercial air traffic/Cargo/Total cargo/Total ...                     104745
# Commercial air traffic/Mail/Total mail/Total ma...                        542
#
# Airports                                           Amsterdam Airport Schiphol  \
# Periods                                                            2020 June*
# Commercial air traffic/Flights/All flights/Tota...                       8108
# Commercial air traffic/Passengers/Total passeng...                     471410
# Commercial air traffic/Cargo/Total cargo/Total ...                     108164
# Commercial air traffic/Mail/Total mail/Total ma...                        855
#
# Airports                                           Amsterdam Airport Schiphol  \
# Periods                                                            2020 July*
# Commercial air traffic/Flights/All flights/Tota...                      15702
# Commercial air traffic/Passengers/Total passeng...                    1338857
# Commercial air traffic/Cargo/Total cargo/Total ...                     119634
# Commercial air traffic/Mail/Total mail/Total ma...                       1083
#
# Airports                                           Amsterdam Airport Schiphol  \
# Periods                                                          2020 August*
# Commercial air traffic/Flights/All flights/Tota...                      23125
# Commercial air traffic/Passengers/Total passeng...                    1854786
# Commercial air traffic/Cargo/Total cargo/Total ...                     119975
# Commercial air traffic/Mail/Total mail/Total ma...                       1283
#
# Airports                                            ...  \
# Periods                                             ...
# Commercial air traffic/Flights/All flights/Tota...  ...
# Commercial air traffic/Passengers/Total passeng...  ...
# Commercial air traffic/Cargo/Total cargo/Total ...  ...
# Commercial air traffic/Mail/Total mail/Total ma...  ...
#
# Airports                                           Groningen Airport Eelde  \
# Periods                                                     2021 December*
# Commercial air traffic/Flights/All flights/Tota...                      59
# Commercial air traffic/Passengers/Total passeng...                    3511
# Commercial air traffic/Cargo/Total cargo/Total ...                       0
# Commercial air traffic/Mail/Total mail/Total ma...                       0
#
# Airports                                           Groningen Airport Eelde  \
# Periods                                                              2021*
# Commercial air traffic/Flights/All flights/Tota...                     674
# Commercial air traffic/Passengers/Total passeng...                   27260
# Commercial air traffic/Cargo/Total cargo/Total ...                       0
# Commercial air traffic/Mail/Total mail/Total ma...                       0
#
# Airports                                           Groningen Airport Eelde  \
# Periods                                                      2022 January*
# Commercial air traffic/Flights/All flights/Tota...                      75
# Commercial air traffic/Passengers/Total passeng...                    3666
# Commercial air traffic/Cargo/Total cargo/Total ...                       0
# Commercial air traffic/Mail/Total mail/Total ma...                       0
#
# Airports                                           Groningen Airport Eelde  \
# Periods                                                     2022 February*
# Commercial air traffic/Flights/All flights/Tota...                      79
# Commercial air traffic/Passengers/Total passeng...                    3436
# Commercial air traffic/Cargo/Total cargo/Total ...                       0
# Commercial air traffic/Mail/Total mail/Total ma...                       0
#
# Airports                                           Groningen Airport Eelde  \
# Periods                                                        2022 March*
# Commercial air traffic/Flights/All flights/Tota...                      63
# Commercial air traffic/Passengers/Total passeng...                    3306
# Commercial air traffic/Cargo/Total cargo/Total ...                       0
# Commercial air traffic/Mail/Total mail/Total ma...                       0
#
# Airports                                           Groningen Airport Eelde  \
# Periods                                                        2022 April*
# Commercial air traffic/Flights/All flights/Tota...                      62
# Commercial air traffic/Passengers/Total passeng...                    5010
# Commercial air traffic/Cargo/Total cargo/Total ...                       0
# Commercial air traffic/Mail/Total mail/Total ma...                       0
#
# Airports                                           Groningen Airport Eelde  \
# Periods                                                          2022 May*
# Commercial air traffic/Flights/All flights/Tota...                     120
# Commercial air traffic/Passengers/Total passeng...                    8746
# Commercial air traffic/Cargo/Total cargo/Total ...                       0
# Commercial air traffic/Mail/Total mail/Total ma...                       0
#
# Airports                                           Groningen Airport Eelde  \
# Periods                                                         2022 June*
# Commercial air traffic/Flights/All flights/Tota...                     148
# Commercial air traffic/Passengers/Total passeng...                    9400
# Commercial air traffic/Cargo/Total cargo/Total ...                       0
# Commercial air traffic/Mail/Total mail/Total ma...                       0
#
# Airports                                           Groningen Airport Eelde  \
# Periods                                                         2022 July*
# Commercial air traffic/Flights/All flights/Tota...                     132
# Commercial air traffic/Passengers/Total passeng...                   11314
# Commercial air traffic/Cargo/Total cargo/Total ...                       0
# Commercial air traffic/Mail/Total mail/Total ma...                       0
#
# Airports                                           Groningen Airport Eelde
# Periods                                                       2022 August*
# Commercial air traffic/Flights/All flights/Tota...                     135
# Commercial air traffic/Passengers/Total passeng...                   13390
# Commercial air traffic/Cargo/Total cargo/Total ...                       0
# Commercial air traffic/Mail/Total mail/Total ma...                       0
#
# [5 rows x 180 columns]
